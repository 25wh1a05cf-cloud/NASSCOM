# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a05cf-cloud/NASSCOM/blob/main/WEEK-1/lists%2C_sets%2C_tuples%2C_and_dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits = ['apple', 'banana', 'cherry', 'apple']
print("Original list:", fruits)
print("First fruit:", fruits[0])
# Out:
# Original list: ['apple', 'banana', 'cherry', 'apple']
# First fruit: apple

# %%
dimensions = (10, 20, 30)
print("Tuple:", dimensions)
# Out:
# Tuple: (10, 20, 30)

# %%
fruits.remove('apple')
print("After removing apple:", fruits)
print("Number of fruits:", len(fruits))
# Out:
# After removing apple: ['banana', 'cherry', 'apple']
# Number of fruits: 3

# %%
lists,_sets,_tuples,_and_dictionarie
print("Tuple:", dimensions)
# Out:
# Tuple: (1, 7, 5)

# %%
print("Second element:", dimensions[1])
# Out:
# Second element: 7

# %%
unique_numbers = {7,8,6,45,7,8}
print("Set (no duplicates):", unique_numbers)
# Out:
# Set (no duplicates): {8, 45, 6, 7}

# %%
unique_numbers.add(10)
print("After adding 10:", unique_numbers)
# Out:
# After adding 10: {6, 7, 8, 10, 45}

# %%
unique_numbers.remove(6)
print("After removing 6:", unique_numbers)
# Out:
# After removing 6: {7, 8, 10, 45}

# %%
set_a = {7,8,9}
set_b = {9,10,11}
print("Union:", set_a | set_b)
print("Intersection:", set_a & set_b)
print("Difference (A - B):", set_a - set_b)
# Out:
# Union: {7, 8, 9, 10, 11}
# Intersection: {9}
# Difference (A - B): {8, 7}

# %%
student = {
    'name': 'Himani',
    'age': 18,
    'course': 'Python'
}
print("Dictionary:", student)
# Out:
# Dictionary: {'name': 'Himani', 'age': 18, 'course': 'Python'}

# %%
print("Student name:", student['name'])
# Out:
# Student name: Himani

# %%
student['grade'] = 'A'
print("After adding grade:", student)

# Remove a key
del student['age']
print("After deleting age:", student)

# Loop through dictionary
for key, value in student.items():
    print(f"{key}: {value}")
# Out:
# After adding grade: {'name': 'Himani', 'age': 18, 'course': 'Python', 'grade': 'A'}
# After deleting age: {'name': 'Himani', 'course': 'Python', 'grade': 'A'}
# name: Himani
# course: Python
# grade: A

# %%
keys = ['id', 'name', 'marks']
values = [86, 'himani', 86]
student_info = dict(zip(keys, values))
print("Student Info from zip:", student_info)
# Out:
# Student Info from zip: {'id': 86, 'name': 'himani', 'marks': 86}
