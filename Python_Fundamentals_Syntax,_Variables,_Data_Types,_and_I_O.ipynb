# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a05cf-cloud/NASSCOM/blob/main/Python_Fundamentals_Syntax%2C_Variables%2C_Data_Types%2C_and_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, himani!")

if True:
    print("This is indented correctly.")
else:
    print("This won't run.")
# Out:
# Hello, himani!
# This is indented correctly.

# %%
name = "Himani"
age = 18
height = 5.6

print("Name:", name)
print("Age:", age)
print("Height:", height)

name = 123
print("New value of name:", name)
# Out:
# Name: Himani
# Age: 18
# Height: 5.6
# New value of name: 123

# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
b = 8.65
print(type(b))
# Out:
# <class 'float'>

# %%
c = "Python"
print(type(c))

d = True
print(type(d))

e = [1, 2, 3, "four"]
print(type(e), e)

f = {"name": "Alice", "age": 25}
print(type(f), f)
# Out:
# <class 'str'>
# <class 'bool'>
# <class 'list'> [1, 2, 3, 'four']
# <class 'dict'> {'name': 'Alice', 'age': 25}

# %%
print("Welcome to India I/O!")
# Out:
# Welcome to India I/O!

# %%
user_name = input("Enter your name: ")
print("Hello,", user_name)
# Out:
# Enter your name: himani
# Hello, himani

# %%
user_age = int(input("Enter your age: "))
print("You will be", user_age + 1, "next year.")
# Out:
# Enter your age: 18
# You will be 19 next year.
